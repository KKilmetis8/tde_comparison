# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
L_tilda_n = np.loadtxt('Ltilda_m4.txt')
array = L_tilda_n[0]
L233 = L_tilda_n[1]
L263 = L_tilda_n[3]

i233 = np.trapz(np.log(10)*10**(array)*L233, array)
i263 = np.trapz(np.log(10)*10**(array)*L263,array)

print(i233)
print(i263)
# Out:
# 3.2102148532231186e+41
# 2.4757182826714316e+41

# %%
print(array[1]-array[0])
print(array[8000]-array[7999])
# Out:
# 2.004363945412525
# 5.429013558710949e-05

# %%
plt.plot(10**array, L233)
plt.plot(10**array, L263, c = 'r')
plt.grid()
plt.loglog()
plt.show()
